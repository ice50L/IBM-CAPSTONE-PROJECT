# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Visualization Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be focusing on the visualization of data.
#
# The data set will be presented to you in the form of a RDBMS.
#
# You will have to use SQL queries to extract the data.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Visualize the distribution of data.
#
# -   Visualize the relationship between two features.
#
# -   Visualize composition of data.
#
# -   Visualize comparison of data.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Demo: How to work with database

# %% [markdown]
# Download database file.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Out:
# --2023-04-26 18:38:17--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m4_survey_data.sqlite
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36679680 (35M) [application/octet-stream]
# Saving to: ‘m4_survey_data.sqlite.3’
#
# m4_survey_data.sqli 100%[===================>]  34.98M  1.94MB/s    in 12s
#
# 2023-04-26 18:38:30 (2.86 MB/s) - ‘m4_survey_data.sqlite.3’ saved [36679680/36679680]

# %% [markdown]
# Connect to the database.

# %%
import sqlite3
conn = sqlite3.connect("m4_survey_data.sqlite") # open a database connection

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# ## Demo: How to run an sql query

# %%
# print how many rows are there in the table named 'master'
QUERY = """
SELECT COUNT(*)
FROM master
"""

# the read_sql_query runs the sql query and returns the data as a dataframe
df = pd.read_sql_query(QUERY,conn)
df.head()
# Out:
#    COUNT(*)
# 0     11398

# %% [markdown]
# ## Demo: How to list all tables

# %%
# print all the tables names in the database
QUERY = """
SELECT name as Table_Name FROM
sqlite_master WHERE
type = 'table'
"""
# the read_sql_query runs the sql query and returns the data as a dataframe
pd.read_sql_query(QUERY,conn)
# Out:
#                 Table_Name
# 0                 EduOther
# 1                  DevType
# 2                  LastInt
# 3               JobFactors
# 4                 WorkPlan
# 5            WorkChallenge
# 6       LanguageWorkedWith
# 7   LanguageDesireNextYear
# 8       DatabaseWorkedWith
# 9   DatabaseDesireNextYear
# 10      PlatformWorkedWith
# 11  PlatformDesireNextYear
# 12      WebFrameWorkedWith
# 13  WebFrameDesireNextYear
# 14      MiscTechWorkedWith
# 15  MiscTechDesireNextYear
# 16              DevEnviron
# 17              Containers
# 18               SOVisitTo
# 19            SONewContent
# 20                  Gender
# 21               Sexuality
# 22               Ethnicity
# 23                  master

# %% [markdown]
# ## Demo: How to run a group by query

# %%
QUERY = """
SELECT Age,COUNT(*) as count
FROM master
group by age
order by age
"""
pd.read_sql_query(QUERY,conn)
# Out:
#      Age  count
# 0    NaN    287
# 1   16.0      3
# 2   17.0      6
# 3   18.0     29
# 4   19.0     78
# 5   20.0    109
# 6   21.0    203
# 7   22.0    406
# 8   23.0    581
# 9   24.0    679
# 10  25.0    738
# 11  26.0    720
# 12  27.0    724
# 13  28.0    787
# 14  29.0    697
# 15  30.0    651
# 16  31.0    531
# 17  32.0    489
# 18  33.0    483
# 19  34.0    395
# 20  35.0    393
# 21  36.0    308
# 22  37.0    280
# 23  38.0    279
# 24  39.0    232
# 25  40.0    187
# 26  41.0    136
# 27  42.0    162
# 28  43.0    100
# 29  44.0     95
# 30  45.0     85
# 31  46.0     66
# 32  47.0     68
# 33  48.0     64
# 34  49.0     66
# 35  50.0     57
# 36  51.0     29
# 37  52.0     41
# 38  53.0     32
# 39  54.0     26
# 40  55.0     13
# 41  56.0     16
# 42  57.0     11
# 43  58.0     12
# 44  59.0     11
# 45  60.0      2
# 46  61.0     10
# 47  62.0      5
# 48  63.0      7
# 49  65.0      2
# 50  66.0      1
# 51  67.0      1
# 52  69.0      1
# 53  71.0      2
# ...

# %% [markdown]
# ## Demo: How to describe a table

# %%
table_name = 'master'  # the table you wish to describe

QUERY = """
SELECT sql FROM sqlite_master
WHERE name= '{}'
""".format(table_name)

df = pd.read_sql_query(QUERY,conn)
print(df.iat[0,0])
# Out:
# CREATE TABLE "master" (
# "index" INTEGER,
#   "Respondent" INTEGER,
#   "MainBranch" TEXT,
#   "Hobbyist" TEXT,
#   "OpenSourcer" TEXT,
#   "OpenSource" TEXT,
#   "Employment" TEXT,
#   "Country" TEXT,
#   "Student" TEXT,
#   "EdLevel" TEXT,
#   "UndergradMajor" TEXT,
#   "OrgSize" TEXT,
#   "YearsCode" TEXT,
#   "Age1stCode" TEXT,
#   "YearsCodePro" TEXT,
#   "CareerSat" TEXT,
#   "JobSat" TEXT,
#   "MgrIdiot" TEXT,
#   "MgrMoney" TEXT,
#   "MgrWant" TEXT,
#   "JobSeek" TEXT,
#   "LastHireDate" TEXT,
#   "FizzBuzz" TEXT,
#   "ResumeUpdate" TEXT,
#   "CurrencySymbol" TEXT,
#   "CurrencyDesc" TEXT,
#   "CompTotal" REAL,
#   "CompFreq" TEXT,
#   "ConvertedComp" REAL,
#   "WorkWeekHrs" REAL,
#   "WorkRemote" TEXT,
#   "WorkLoc" TEXT,
#   "ImpSyn" TEXT,
#   "CodeRev" TEXT,
#   "CodeRevHrs" REAL,
#   "UnitTests" TEXT,
#   "PurchaseHow" TEXT,
#   "PurchaseWhat" TEXT,
#   "OpSys" TEXT,
#   "BlockchainOrg" TEXT,
#   "BlockchainIs" TEXT,
#   "BetterLife" TEXT,
#   "ITperson" TEXT,
# ...

# %% [markdown]
# # Hands-on Lab

# %% [markdown]
# ## Visualizing distribution of data

# %% [markdown]
# ### Histograms

# %% [markdown]
# Plot a histogram of `ConvertedComp.`

# %%
# your code goes here
QUERY = """
SELECT * FROM master
"""
df = pd.read_sql_query(QUERY,conn)
df.hist(column='ConvertedComp')
# Out:
# array([[<AxesSubplot:title={'center':'ConvertedComp'}>]], dtype=object)

# %% [markdown]
# ### Box Plots

# %% [markdown]
# Plot a box plot of `Age.`

# %%
# your code goes here

QUERY = """
SELECT * FROM master
"""
df = pd.read_sql_query(QUERY,conn)
df.boxplot(column='Age')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Visualizing relationships in data

# %% [markdown]
# ### Scatter Plots

# %% [markdown]
# Create a scatter plot of `Age` and `WorkWeekHrs.`

# %%
# your code goes here
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


QUERY = """
SELECT * FROM master
"""
df = pd.read_sql_query(QUERY, conn)
plot = sns.scatterplot(x = 'Age', y = 'WorkWeekHrs', data = df)

# %% [markdown]
# ### Bubble Plots

# %% [markdown]
# Create a bubble plot of `WorkWeekHrs` and `CodeRevHrs`, use `Age` column as bubble size.

# %%
# your code goes here

QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age FROM master
"""
df1=pd.read_sql_query(QUERY,conn)

sns.scatterplot(data=df1, x='WorkWeekHrs', y='CodeRevHrs', size='Age', hue='Age', alpha=0.5, sizes=(10, 500)) 

plt.title('WorkWeekHrs and CodeRevHrs By Age', size=14) 
plt.xlabel('WorkWeekHrs', size=10) 
plt.ylabel('CodeRevHrs', size=10)

plt.show()

# %% [markdown]
# ## Visualizing composition of data

# %% [markdown]
# ### Pie Charts

# %% [markdown]
# Create a pie chart of the top 5 databases that respondents wish to learn next year. Label the pie chart with database names. Display percentages of each database on the pie chart.

# %%
# your code goes here
import matplotlib as mpl
import matplotlib.pyplot as plt

QUERY = """ 
SELECT DatabaseDesireNextYear, COUNT(*) as count 
from DatabaseDesireNextYear 
group by DatabaseDesireNextYear 
order by count(DatabaseDesireNextYear) DESC LIMIT 5 
""" 

df=pd.read_sql_query(QUERY,conn)  
df.set_index('DatabaseDesireNextYear', inplace=True) 

colors_list=['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']

df['count'].plot(kind='pie', figsize=(20,6), autopct='%1.1f%%', labels=None, startangle=90, colors=colors_list, shadow=True, pctdistance=1.12)  

plt.legend(labels=df.index, loc='upper right')
plt.title('Top 5 Databases Respondents Wish To Learn') 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### Stacked Charts

# %% [markdown]
# Create a stacked chart of median `WorkWeekHrs` and `CodeRevHrs` for the age group 30 to 35.

# %%
# your code goes here

QUERY = """
SELECT WorkWeekHrs, CodeRevHrs, Age FROM master
WHERE Age BETWEEN 30 AND 35
"""
df = pd.read_sql_query(QUERY,conn)
df1 = df.groupby('Age').median()

df1.plot(kind='bar', figsize=(10, 6), stacked=True)

plt.title('Stacked Bar Chart of Median WorkWeekHrs and CodeRevHrs for Those Age 30 to 35')
plt.show()

# %% [markdown]
# ## Visualizing comparison of data

# %% [markdown]
# ### Line Chart

# %% [markdown]
# Plot the median `ConvertedComp` for all ages from 45 to 60.

# %%
# your code goes here
QUERY = """
SELECT ConvertedComp, Age
FROM master
WHERE Age BETWEEN 45 AND 60
"""
df = pd.read_sql_query(QUERY,conn)
df1 = df.groupby('Age').median()

df1.plot(kind='line', figsize=(20, 6))

plt.title('Median ConvertedComp for Those Age 45 to 60')
plt.ylabel('ConvertedComp')
plt.show()

# %% [markdown]
# ### Bar Chart

# %% [markdown]
# Create a horizontal bar chart using column `MainBranch.`

# %%
# your code goes here
QUERY = """
SELECT MainBranch, COUNT(*) as MainBranch
from master
group by MainBranch
"""

df=pd.read_sql_query(QUERY,conn)

df.plot(kind='barh', figsize=(10,6), color='lightskyblue')

plt.show()

# %%
QUERY = """
SELECT *
FROM LanguageWorkedWith
"""
pd.set_option('display.max_columns', 500)
df22 = pd.read_sql_query(QUERY,conn)
df22.head(30)
# Out:
#     Respondent     LanguageWorkedWith
# 0            4                      C
# 1            4                    C++
# 2            4                     C#
# 3            4                 Python
# 4            4                    SQL
# 5            9  Bash/Shell/PowerShell
# 6            9                     C#
# 7            9               HTML/CSS
# 8            9             JavaScript
# 9            9                 Python
# 10           9                   Ruby
# 11           9                   Rust
# 12           9                    SQL
# 13           9             TypeScript
# 14           9            WebAssembly
# 15           9              Other(s):
# 16          13  Bash/Shell/PowerShell
# 17          13               HTML/CSS
# 18          13             JavaScript
# 19          13                    PHP
# 20          13                    SQL
# 21          13             TypeScript
# 22          16  Bash/Shell/PowerShell
# 23          16                     C#
# ...

# %% [markdown]
# Close the database connection.

# %%
QUERY = """
SELECT COUNT(*)
FROM LanguageWorkedWith
WHERE LanguageWorkedWith = 'SQL'
GROUP BY LanguageWorkedWith

"""
df22 = pd.read_sql_query(QUERY,conn)
df22
# Out:
#    COUNT(*)
# 0      7106

# %%
QUERY = """
SELECT *
FROM DatabaseWorkedWith
"""
pd.set_option('display.max_columns', 500)
df223 = pd.read_sql_query(QUERY,conn)
df223
# Out:
#        Respondent    DatabaseWorkedWith
# 0               4                 MySQL
# 1               4                SQLite
# 2               9              DynamoDB
# 3               9            PostgreSQL
# 4               9                SQLite
# ...           ...                   ...
# 31370       25137                 MySQL
# 31371       25138            PostgreSQL
# 31372       25141  Microsoft SQL Server
# 31373       25141                 Redis
# 31374       25142            PostgreSQL
#
# [31375 rows x 2 columns]

# %%
QUERY = """
SELECT DISTINCT *
FROM DatabaseWorkedWith
WHERE DatabaseWorkedWith = 'MySQL'
"""
df224 = pd.read_sql_query(QUERY,conn)
df224
# Out:
#       Respondent DatabaseWorkedWith
# 0              4              MySQL
# 1             13              MySQL
# 2             16              MySQL
# 3             19              MySQL
# 4             22              MySQL
# ...          ...                ...
# 5464       25111              MySQL
# 5465       25120              MySQL
# 5466       25124              MySQL
# 5467       25134              MySQL
# 5468       25137              MySQL
#
# [5469 rows x 2 columns]

# %%
QUERY = """
SELECT *
FROM master
"""
pd.set_option('display.max_columns', 500)
df221 = pd.read_sql_query(QUERY,conn)
df221.head(30)
# Out:
#     index  Respondent                                         MainBranch  \
# 0       0           4                     I am a developer by profession
# 1       1           9                     I am a developer by profession
# 2       2          13                     I am a developer by profession
# 3       3          16                     I am a developer by profession
# 4       4          17                     I am a developer by profession
# 5       5          19                     I am a developer by profession
# 6       6          20  I am not primarily a developer, but I write co...
# 7       7          22                     I am a developer by profession
# 8       8          23                     I am a developer by profession
# 9       9          24                     I am a developer by profession
# 10     10          25                     I am a developer by profession
# 11     11          26                     I am a developer by profession
# ...

# %%
QUERY = """
SELECT *
FROM DevType
"""
pd.set_option('display.max_columns', 500)
df111 = pd.read_sql_query(QUERY,conn)
ccc = df111['DevType'].value_counts()

# %%
QUERY = """
SELECT DevType, count(*) as amount
FROM DevType
GROUP BY DevType
"""

df111 = pd.read_sql_query(QUERY,conn)

df111.plot('DevType', 'amount', kind = 'bar')
plt.show()

# %%
QUERY = """
SELECT ConvertedComp, Age
FROM master
WHERE Age BETWEEN 25 AND 30
"""
df = pd.read_sql_query(QUERY,conn)
df1 = df.groupby('Age').median()

df1.plot(kind='line', figsize=(20, 6))

plt.title('Median ConvertedComp for Those Age 25 to 30')
plt.ylabel('ConvertedComp')
plt.show()

# %%
QUERY = """
SELECT ConvertedComp, Age
FROM master
WHERE Age BETWEEN 20 AND 60
"""
df = pd.read_sql_query(QUERY,conn)
df1 = df.groupby('Age').median()

df1.plot(kind='line', figsize=(20, 6))

plt.title('Median Converted Compensation ($) for Those Age 20 to 60')
plt.ylabel('ConvertedComp')
plt.show()

# %%
QUERY = """
SELECT ConvertedComp, Age
FROM master
WHERE Age BETWEEN 20 AND 60
"""
df = pd.read_sql_query(QUERY,conn)
df1 = df.groupby('Age').median()
df1.head(20)
# Out:
#       ConvertedComp
# Age
# 20.0        21232.0
# 21.0        18000.0
# 22.0        22512.0
# 23.0        31566.0
# 24.0        33218.0
# 25.0        39920.0
# 26.0        43834.0
# 27.0        49620.0
# 28.0        51559.0
# 29.0        55674.0
# 30.0        56376.0
# 31.0        66972.0
# 32.0        65424.0
# 33.0        68745.0
# 34.0        71792.5
# 35.0        70000.0
# 36.0        80000.0
# 37.0        80178.5
# 38.0        82000.0
# 39.0        72091.0

# %%
#Top 10 languages
QUERY = """
SELECT LanguageWorkedWith, count(*) as Respondents
FROM LanguageWorkedWith
group by LanguageWorkedWith
ORDER BY respondents DESC
LIMIT 10
"""
df123 = pd.read_sql_query(QUERY,conn); df123
# Out:
#       LanguageWorkedWith  Respondents
# 0             JavaScript         8687
# 1               HTML/CSS         7830
# 2                    SQL         7106
# 3  Bash/Shell/PowerShell         4642
# 4                 Python         4542
# 5                   Java         4506
# 6                     C#         4288
# 7             TypeScript         3232
# 8                    PHP         2913
# 9                    C++         1946

# %%
df123.plot('LanguageWorkedWith', 'Respondents', kind = 'barh', color = 'black')
plt.show()

# %%
#Top 10 languages Next Year
QUERY = """
SELECT LanguageDesireNextYear, count(*) as Respondents
FROM LanguageDesireNextYear
group by LanguageDesireNextYear
ORDER BY respondents DESC
LIMIT 10
"""
df1234 = pd.read_sql_query(QUERY,conn); df1234
# Out:
#   LanguageDesireNextYear  Respondents
# 0             JavaScript         6630
# 1               HTML/CSS         5328
# 2                 Python         5239
# 3                    SQL         5012
# 4             TypeScript         4088
# 5                     C#         3591
# 6  Bash/Shell/PowerShell         3097
# 7                   Java         2953
# 8                     Go         2759
# 9                 Kotlin         1890

# %%
df1234.plot('LanguageDesireNextYear', 'Respondents', kind = 'barh', color = 'red')
plt.show()

# %%
#Top 10 database languages
QUERY = """
SELECT DatabaseWorkedWith, COUNT(*) as respondents
FROM DatabaseWorkedWith
GROUP BY DatabaseWorkedWith
ORDER BY respondents DESC
LIMIT 10
"""
df55 = pd.read_sql_query(QUERY,conn); df55
# Out:
#      DatabaseWorkedWith  respondents
# 0                 MySQL         5469
# 1  Microsoft SQL Server         4110
# 2            PostgreSQL         4097
# 3                SQLite         3248
# 4               MongoDB         3016
# 5                 Redis         2508
# 6         Elasticsearch         1954
# 7                Oracle         1744
# 8               MariaDB         1709
# 9              Firebase         1314

# %%
df55.plot('DatabaseWorkedWith', 'respondents', kind = 'barh', color = 'green')
plt.show()

# %%
QUERY = """
SELECT DatabaseDesireNextYear, COUNT(*) as Respondents
FROM DatabaseDesireNextYear
GROUP BY DatabaseDesireNextYear
ORDER BY Respondents DESC
LIMIT 10
"""
df66 = pd.read_sql_query(QUERY,conn); df66
# Out:
#   DatabaseDesireNextYear  Respondents
# 0             PostgreSQL         4328
# 1                MongoDB         3649
# 2                  Redis         3331
# 3                  MySQL         3281
# 4          Elasticsearch         2856
# 5   Microsoft SQL Server         2706
# 6                 SQLite         2437
# 7               Firebase         1650
# 8                MariaDB         1385
# 9               DynamoDB         1044

# %%
df66.plot('DatabaseDesireNextYear', 'Respondents', kind = 'barh', color = 'purple')
plt.show()

# %%
conn.close()

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
